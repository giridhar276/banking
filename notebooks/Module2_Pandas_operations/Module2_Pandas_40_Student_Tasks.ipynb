# %% [markdown]
# # Module 2: Pandas Banking Operations - Student Assignment
#
# This notebook contains **40 tasks without solutions**. Keep `banking_operations.csv` in the same folder as this notebook.
#
# ## Instructions
#
# - Read each task carefully.
# - Write your solution in the empty code cell immediately below the task.
# - Run the cell and verify the output.
# - Complete the tasks in order because later tasks may use columns created earlier.
# - Use simple Pandas, Matplotlib and Seaborn methods covered in Module 2.

# %% [markdown]
# ## Section 1: Loading and inspecting data

# %% [markdown]
# ## Task 1: Load the banking dataset
#
# Import Pandas as `pd`. Read `banking_operations.csv` and store it in a DataFrame named `df`. Display the DataFrame.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 2: View the first records
#
# Display the first five rows of the dataset.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 3: View the last records
#
# Display the last five rows of the dataset.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 4: Find the dataset dimensions
#
# Display the number of rows and columns in the dataset.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 5: Display column names
#
# Display all column names as a Python list.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 6: Inspect the dataset
#
# Display the dataset summary using `info()`.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 7: Check data types
#
# Display the data type of every column.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 8: Generate descriptive statistics
#
# Display descriptive statistics for the numeric columns.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 9: Select one column
#
# Select and display the `Amount` column.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 10: Select multiple columns
#
# Display only Transaction ID, Customer ID, Transaction Type and Amount.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 11: Count account types
#
# Count the number of records for every Account Type.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 12: Find unique channels
#
# Display all unique values available in the Channel column.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 13: Count unique customers
#
# Find the total number of unique customers.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Section 2: Sorting and filtering

# %% [markdown]
# ## Task 14: Sort transactions
#
# Sort the dataset by Amount from smallest to largest and display the first ten rows.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 15: Find largest transactions
#
# Display the five transactions with the highest Amount.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 16: Filter high-value transactions
#
# Display transactions where Amount is greater than 10,000.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 17: Filter completed transactions
#
# Display transactions whose Status is Completed.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 18: Apply multiple conditions
#
# Display completed transactions with Amount greater than 15,000.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 19: Filter selected channels
#
# Display transactions performed through ATM, UPI or Mobile Banking. Use `isin()`.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 20: Filter an amount range
#
# Display transactions where Amount is between 5,000 and 12,000.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Section 3: Cleaning and transforming

# %% [markdown]
# ## Task 21: Count missing values
#
# Count the missing values in every column.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 22: Display missing Channel records
#
# Display all rows where Channel is missing.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 23: Fill missing Channel values
#
# Create a copy of the DataFrame and replace missing Channel values with `Unknown`.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 24: Fill missing Branch City values
#
# In the copied DataFrame, replace missing Branch City values with `Online`. Confirm that no missing values remain.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 25: Check duplicate rows
#
# Count the number of completely duplicated rows.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 26: Create a service-fee column
#
# Create a copy of the original DataFrame. Add a Service Fee column equal to 1% of Amount.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 27: Create an amount category
#
# Create a new column that labels transactions of at least 15,000 as `High` and all others as `Regular`.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 28: Convert the date column
#
# Convert Transaction Date into Pandas datetime format and display its new data type.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 29: Extract month names
#
# Create a Month column containing the abbreviated month name from Transaction Date.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 30: Extract day names
#
# Create a Day Name column from Transaction Date.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Section 4: Grouping and combining

# %% [markdown]
# ## Task 31: Calculate totals by transaction type
#
# Group the data by Transaction Type and calculate total Amount for every type.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 32: Calculate averages by account type
#
# Group the data by Account Type and calculate the average Amount. Round the result to two decimal places.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 33: Perform multiple aggregations
#
# For every Transaction Type, calculate transaction count, total Amount, average Amount and maximum Amount.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 34: Create a pivot table
#
# Create a pivot table showing total Amount by Account Type and Transaction Type. Replace missing combinations with zero.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 35: Create a cross-tabulation
#
# Create a cross-tabulation showing the count of transactions by Transaction Type and Status.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 36: Merge customer segments
#
# Create a small DataFrame containing Customer ID and Customer Segment for five customers. Left-merge it with the banking dataset.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Section 5: Simple visualization

# %% [markdown]
# ## Task 37: Create a bar chart
#
# Using Matplotlib, create a bar chart showing the number of transactions for each Transaction Type. Add a title and axis labels.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 38: Create a histogram
#
# Using Matplotlib, create a histogram of Amount with 10 bins. Add a title and axis labels.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 39: Create a count plot
#
# Using Seaborn, create a count plot showing the number of transactions for each Status.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 40: Create a box plot
#
# Using Seaborn, create a box plot comparing Amount across Account Types.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Submission checklist
#
# - All 40 code cells contain your solutions.
# - The notebook runs without errors.
# - Charts have meaningful titles and labels.
# - Variable names are clear and understandable.
