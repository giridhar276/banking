# %% [markdown]
# # Object-oriented Programming Concepts
#
# ## Learning objectives
#
# - Understand classes and objects
# - Create attributes and methods
# - Understand encapsulation and inheritance through simple examples
#
# This notebook uses small examples and explains each idea before the code.

# %% [markdown]
# ## 1. Class and object
#
# A **class** is a blueprint. An **object** is a value created from that blueprint. For example, `BankAccount` can be a class and Anita's account can be an object.

# %%
class BankAccount:
    def __init__(self, account_number, customer_name, balance):
        self.account_number = account_number
        self.customer_name = customer_name
        self.balance = balance

account1 = BankAccount("SB1001", "Anita", 15000)

print(account1.account_number)
print(account1.customer_name)
print(account1.balance)

# %% [markdown]
# ## 2. Methods
#
# A method is a function written inside a class. It describes an action that an object can perform.

# %%
class BankAccount:
    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance = self.balance + amount

    def show_balance(self):
        print("Available balance:", self.balance)

account = BankAccount("SB1001", 10000)
account.deposit(2500)
account.show_balance()

# %% [markdown]
# ## 3. Encapsulation
#
# Encapsulation keeps data and the functions that operate on it together. A leading underscore tells users that an attribute is intended for internal use.

# %%
class SecureAccount:
    def __init__(self, balance):
        self._balance = balance

    def get_balance(self):
        return self._balance

    def deposit(self, amount):
        if amount > 0:
            self._balance = self._balance + amount

account = SecureAccount(8000)
account.deposit(2000)
print(account.get_balance())

# %% [markdown]
# ## 4. Inheritance
#
# Inheritance allows one class to reuse and extend another class.

# %%
class Account:
    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.balance = balance

    def show_balance(self):
        print("Balance:", self.balance)

class SavingsAccount(Account):
    def add_interest(self, rate):
        interest = self.balance * rate / 100
        self.balance = self.balance + interest

savings = SavingsAccount("SB2001", 20000)
savings.add_interest(5)
savings.show_balance()

# %% [markdown]
# ## Practice
#
# Create a `Customer` class with a name and customer ID. Add a method that displays both values.

# %%
class Customer:
    def __init__(self, customer_id, name):
        self.customer_id = customer_id
        self.name = name

    def display(self):
        print("Customer ID:", self.customer_id)
        print("Customer Name:", self.name)

customer = Customer(1001, "Rahul")
customer.display()

# %% [markdown]
# ## Summary
#
# You have completed this notebook. Run the examples again with different values to strengthen your understanding.
