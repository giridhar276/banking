# %% [markdown]
# # Assignment 7: Banking Operations Use Case
#
# ## Instructions
#
# - Read every task carefully.
# - Write your solution in the empty code cell below each task.
# - Run the cell and check the output.
# - Use simple Python statements covered in the corresponding learning notebook.
# - Do not use advanced libraries unless a task asks for them.
#
# ## Learning objectives
#
# - Combine Python objects, conditions, loops, functions and files
# - Build a simple banking workflow
# - Generate a basic account statement

# %% [markdown]
# ## Task 1: Create account data
#
# Create a dictionary containing account number, customer name and an opening balance. Also create an empty list for transaction history.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 2: Deposit function
#
# Create a function that accepts the account, transaction list and deposit amount. Validate that the amount is positive, update the balance and record the transaction.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 3: Withdrawal function
#
# Create a function that validates the withdrawal amount. Reject zero, negative or excessive amounts. For a valid withdrawal, update the balance and record the transaction.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 4: Perform transactions
#
# Perform at least two deposits and two withdrawals. Include one withdrawal that should be rejected because the balance is insufficient.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 5: Display transaction history
#
# Use a loop and `enumerate()` to display the transaction number, transaction type and amount for every successful transaction.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 6: Generate a statement
#
# Write the account number, customer name, successful transactions and closing balance to `assignment_bank_statement.txt`. Use a direct filename and do not use `Path`.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 7: Read the statement
#
# Open `assignment_bank_statement.txt` and display its complete contents.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Submission checklist
#
# - All task cells contain your code.
# - Every cell runs without errors.
# - Variable and function names are meaningful.
# - Outputs are easy to understand.
