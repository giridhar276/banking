# %% [markdown]
# # Assignment 4: User-defined Functions
#
# ## Instructions
#
# - Read every task carefully.
# - Write your solution in the empty code cell below each task.
# - Run the cell and check the output.
# - Use simple Python statements covered in the corresponding learning notebook.
# - Do not use advanced libraries unless a task asks for them.
#
# ## Learning objectives
#
# - Create reusable functions
# - Use parameters, return values and default arguments
# - Break a banking problem into small functions

# %% [markdown]
# ## Task 1: Welcome message
#
# Create a function named `welcome_customer` that accepts a customer name and prints a welcome message.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 2: Simple interest
#
# Create a function that receives principal, rate and years, then returns simple interest.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 3: Deposit calculation
#
# Create a function that accepts current balance and deposit amount. Return the updated balance only when the deposit amount is positive.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 4: Withdrawal check
#
# Create a function that returns `True` when the withdrawal amount is positive and does not exceed the available balance. Otherwise return `False`.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 5: Transaction fee
#
# Create a function that calculates a transaction fee. Use a default fee rate of 1%. Call it once with the default rate and once with a custom rate.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Submission checklist
#
# - All task cells contain your code.
# - Every cell runs without errors.
# - Variable and function names are meaningful.
# - Outputs are easy to understand.
