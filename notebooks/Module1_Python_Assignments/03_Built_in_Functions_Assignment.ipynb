# %% [markdown]
# # Assignment 3: Built-in Functions
#
# ## Instructions
#
# - Read every task carefully.
# - Write your solution in the empty code cell below each task.
# - Run the cell and check the output.
# - Use simple Python statements covered in the corresponding learning notebook.
# - Do not use advanced libraries unless a task asks for them.
#
# ## Learning objectives
#
# - Use common Python built-in functions
# - Summarize and sort numeric values
# - Convert values between data types

# %% [markdown]
# ## Task 1: Customer name analysis
#
# Store a customer name in a variable. Print the name, its length and its data type.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 2: Balance summary
#
# For balances `[12500, 8500, 21000, 16000, 9500]`, print the total, number of balances, minimum and maximum.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 3: Average balance
#
# Calculate the average of the balances from Task 2 using `sum()` and `len()`. Round it to two decimal places.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 4: Sort transactions
#
# Sort `[4500, 1200, 7800, 3000, 900]` in ascending and descending order.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 5: Combine customer data
#
# Create one list of three customer names and another list of their balances. Use `zip()` to print each customer with the corresponding balance.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Submission checklist
#
# - All task cells contain your code.
# - Every cell runs without errors.
# - Variable and function names are meaningful.
# - Outputs are easy to understand.
