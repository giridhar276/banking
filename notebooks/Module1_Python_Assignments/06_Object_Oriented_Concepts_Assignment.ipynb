# %% [markdown]
# # Assignment 6: Object-oriented Concepts
#
# ## Instructions
#
# - Read every task carefully.
# - Write your solution in the empty code cell below each task.
# - Run the cell and check the output.
# - Use simple Python statements covered in the corresponding learning notebook.
# - Do not use advanced libraries unless a task asks for them.
#
# ## Learning objectives
#
# - Create classes and objects
# - Add attributes and methods
# - Practice simple encapsulation and inheritance

# %% [markdown]
# ## Task 1: Customer class
#
# Create a `Customer` class with customer ID and name attributes. Create one object and print its details.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 2: Bank account class
#
# Create a `BankAccount` class with account number and balance attributes. Add a method that displays the balance.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 3: Deposit method
#
# Extend the `BankAccount` class with a deposit method. Accept only positive amounts and update the balance.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 4: Encapsulated balance
#
# Create a class that stores balance in `_balance`. Add `get_balance()` and `deposit()` methods, then demonstrate them with an object.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 5: Savings-account inheritance
#
# Create a base `Account` class and a child `SavingsAccount` class. Add a method in the child class that calculates and adds interest.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Submission checklist
#
# - All task cells contain your code.
# - Every cell runs without errors.
# - Variable and function names are meaningful.
# - Outputs are easy to understand.
