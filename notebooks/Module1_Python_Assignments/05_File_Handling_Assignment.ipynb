# %% [markdown]
# # Assignment 5: File Handling
#
# ## Instructions
#
# - Read every task carefully.
# - Write your solution in the empty code cell below each task.
# - Run the cell and check the output.
# - Use simple Python statements covered in the corresponding learning notebook.
# - Do not use advanced libraries unless a task asks for them.
#
# ## Learning objectives
#
# - Write, read and append text files
# - Work with a simple CSV file
# - Use direct filenames without Path

# %% [markdown]
# ## Task 1: Write customer information
#
# Using the direct filename `customer_assignment.txt`, write a customer ID, name and account type on separate lines. Do not use `Path`.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 2: Read customer information
#
# Open `customer_assignment.txt` in read mode and print its complete contents.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 3: Append account status
#
# Append `Account Status: Active` to `customer_assignment.txt`. Read the file again and display the updated contents.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 4: Write branch names
#
# Write Hyderabad, Mumbai and Chennai to `branches_assignment.txt`, one branch per line. Then read and print the file.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 5: Transaction CSV
#
# Using the built-in `csv` module, create `transactions_assignment.csv` with columns Transaction ID, Type and Amount. Add at least three transaction rows and then read and display them.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Submission checklist
#
# - All task cells contain your code.
# - Every cell runs without errors.
# - Variable and function names are meaningful.
# - Outputs are easy to understand.
