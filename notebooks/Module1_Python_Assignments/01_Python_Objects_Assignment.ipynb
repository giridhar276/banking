# %% [markdown]
# # Assignment 1: Python Objects
#
# ## Instructions
#
# - Read every task carefully.
# - Write your solution in the empty code cell below each task.
# - Run the cell and check the output.
# - Use simple Python statements covered in the corresponding learning notebook.
# - Do not use advanced libraries unless a task asks for them.
#
# ## Learning objectives
#
# - Create and inspect basic Python objects
# - Use lists, tuples, sets and dictionaries
# - Apply basic operations to banking information

# %% [markdown]
# ## Task 1: Customer details
#
# Create variables for customer name, age, account number, account balance and active status. Print every value and its data type.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 2: Account balance calculation
#
# Create variables for an opening balance, deposit amount and withdrawal amount. Calculate and print the closing balance.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 3: Transaction list
#
# Create a list containing five transaction amounts. Add one more transaction, remove one transaction and print the updated list.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 4: Unique banking services
#
# Create a set containing ATM, UPI, Net Banking, ATM and Mobile Banking. Print the set and observe how duplicate values are handled.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 5: Bank account dictionary
#
# Create a dictionary containing account number, customer name, account type and balance. Update the balance and print all the account information.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Submission checklist
#
# - All task cells contain your code.
# - Every cell runs without errors.
# - Variable and function names are meaningful.
# - Outputs are easy to understand.
