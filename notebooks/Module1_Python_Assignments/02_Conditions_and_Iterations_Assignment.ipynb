# %% [markdown]
# # Assignment 2: Conditions and Iterations
#
# ## Instructions
#
# - Read every task carefully.
# - Write your solution in the empty code cell below each task.
# - Run the cell and check the output.
# - Use simple Python statements covered in the corresponding learning notebook.
# - Do not use advanced libraries unless a task asks for them.
#
# ## Learning objectives
#
# - Use conditions to make decisions
# - Use loops to process banking values
# - Apply break and continue appropriately

# %% [markdown]
# ## Task 1: Withdrawal validation
#
# Create balance and withdrawal amount variables. Print `Withdrawal Approved` when sufficient balance is available; otherwise print `Insufficient Balance`.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 2: Loan eligibility category
#
# Create a credit-score variable. Print `High Eligibility` for scores of 750 or more, `Needs Review` for scores from 650 to 749, and `Not Eligible` for lower scores.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 3: Classify transactions
#
# Create a list of positive and negative transaction values. Use a loop to print `Credit` for positive values and `Debit` for negative values.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 4: Monthly installments
#
# Use a while loop to print installment numbers from 1 through 6.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Task 5: Check transaction amounts
#
# Process `[500, 0, 2500, -100, 4000]`. Skip zero using `continue`. Stop when a negative amount is found using `break`. Print valid amounts.
#
# Write your code in the empty cell below.

# %% [markdown]
# ## Submission checklist
#
# - All task cells contain your code.
# - Every cell runs without errors.
# - Variable and function names are meaningful.
# - Outputs are easy to understand.
